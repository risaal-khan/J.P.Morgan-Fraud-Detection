# %%
import pandas as pd
import pickle

with open("train_test_data.pkl", "rb") as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

# %%
# pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.5.0-py3-none-manylinux_2_28_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.13.1)
# Downloading lightgbm-4.5.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 34.9 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.5.0

# %%
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

param_grid = {
    'num_leaves': [31, 50, 70],  # More leaves = better fraud detection
    'learning_rate': [0.01, 0.05, 0.1],  # Lower rate = better separation
    'n_estimators': [500, 1000]  # More estimators = better detection
}

model = lgb.LGBMClassifier(class_weight={0: 1, 1: 2})

grid = GridSearchCV(model, param_grid, cv=3, scoring='recall')  # Optimize for recall
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.123548 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.135641 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.123566 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.184370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.124902 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.126453 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.189372 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.170651 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.119648 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.184613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.127294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.216874 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.127059 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.178325 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.118150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.132190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.116758 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.190127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.138511 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.122960 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.182179 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.130693 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.120005 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.185800 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.151525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.116058 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.180388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.130014 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.203281 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.133400 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.227780 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.215845 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.180842 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.129501 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.178337 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.120535 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.134060 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.128854 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.189421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.122240 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.191651 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.144691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.137785 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.130209 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.125335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.126234 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.134001 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.138887 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.132812 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121032 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.126397 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.142022 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.184293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# [LightGBM] [Info] Number of positive: 1173886, number of negative: 1173886
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.297668 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 2347772, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# {'learning_rate': 0.1, 'n_estimators': 1000, 'num_leaves': 70}

# %%
# Best parameters: {'learning_rate': 0.1, 'n_estimators': 1000, 'num_leaves': 70}

best_clf = grid.best_estimator_

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(best_clf, X_train, y_train, cv=3, scoring='recall')
print(f'Cross-validation scores: {scores}')
print(f'Mean cross-validation score: {scores.mean()}')
# Out:
# [LightGBM] [Info] Number of positive: 782590, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.114910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666666 -> initscore=0.693146
# [LightGBM] [Info] Start training from score 0.693146
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782590
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121816 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565181, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693148
# [LightGBM] [Info] Start training from score 0.693148
# [LightGBM] [Info] Number of positive: 782591, number of negative: 782591
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.117356 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1409
# [LightGBM] [Info] Number of data points in the train set: 1565182, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.666667 -> initscore=0.693147
# [LightGBM] [Info] Start training from score 0.693147
# Cross-validation scores: [0.96089917 0.9610064  0.96093996]
# Mean cross-validation score: 0.9609485078187677

# %%
# Cross-validation scores: [0.96089917 0.9610064  0.96093996]
# Mean cross-validation score: 0.9609485078187677

preds = best_clf.predict(X_test)
pd.Series(preds).value_counts()
# Out:
# 0    299708
# 1    287236
# Name: count, dtype: int64

# %%
pd.crosstab(y_test, preds)
# Out:
# col_0       0       1
# Label
# 0      288583    4889
# 1       11125  282347

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    293472
#            1       0.98      0.96      0.97    293472
#
#     accuracy                           0.97    586944
#    macro avg       0.97      0.97      0.97    586944
# weighted avg       0.97      0.97      0.97    586944

# %%
import joblib

# joblib.dump(best_clf, "frauddetection.pkl")
# Out:
# ['frauddetection.pkl']

# %%
# Get predicted probabilities
y_pred_proba = best_clf.predict_proba(X_test)[:, 1]  # Probability of class 1

# Adjust threshold to reduce False Negatives
threshold = 0.4  # Try 0.4 or lower like 0.35
y_pred_adjusted = (y_pred_proba > threshold).astype(int)

# Check new confusion matrix
print(pd.crosstab(y_test, y_pred_adjusted))
print(classification_report(y_test, y_pred_adjusted))
# Out:
# col_0       0       1
# Label
# 0      284468    9004
# 1        8534  284938
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97    293472
#            1       0.97      0.97      0.97    293472
#
#     accuracy                           0.97    586944
#    macro avg       0.97      0.97      0.97    586944
# weighted avg       0.97      0.97      0.97    586944
